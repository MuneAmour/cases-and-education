# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Привет!👋</b>
#
# Меня зовут Огурлиев Анзор, я буду ревьюером твоего проекта. Сразу хочу предложить тебе общаться на "ты", если тебе это неудобно, скажи мне об этом. Нам предстоит пройти с тобой через тернистый и от того интересный путь анализа данных! Можешь не переживать, я всегда помогу тебе, если у тебя возникнут вопросы)
#
# По ходу твоей работы я буду оставлять свои комментарии, по выполненным тобой шагам. Попрошу тебя не удалять их, так мне будет проще отслеживать твой прогресс в случае повторной проверки.
#
# Очень важно вести диалог и обсуждать те пункты, которые у тебя могли не получиться, поэтому, ты можешь оставлять свои комментарии, и мы обязательно во всем разберемся! Самое главное - выделяй свои комментарии удобным для тебя способом (цвет, рамка), но так, чтобы они отчетлитво отличались от моих комментариев. Так мы ни в чем не запутаемся)
#
# Свои комментарии я буду выделять так: <font color='green'>зеленый</font>, <font color='gold'>желтый</font> и <font color='red'>красный</font> цвет, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Этот комментарий я буду оставлять, если твое решение оптимально для данного шага.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> Это не означает, что ты совершил ошибку. Такими комментариями я буду отмечать места, где ты справился с задачей, но её можно решить ещё лучше. Также в таких комментариях я буду оставлять для тебя другие советы.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# Если решение, которое ты применил на определенном шаге, требует значительных изменений, то я буду оставлять такой комментарий. Тебе нужно будет подумать еще раз как правильным образом решить данный этап. Если ревью содержит такие комментарии, то я не смогу принять проект с первого раза.
# </div>
#
# P.S. В оглавлении комментария ты увидишь `V1` (`V1`, `V2`, `V3`) - это версия моего комментария, которая понадобится нам с тобой, чтобы не запутаться, если потребуется оставить тебе комментарии после первой проверки.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# Проект всегда нужно начинать с описания.

# %% [markdown]
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр.
#
# ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Молодец, что начинаешь проект с описания.

# %% [markdown]
# # Сборный проект №1

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# # 1.1 Обзор данных

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
# %matplotlib inline
import matplotlib.pyplot as plt
sns.set()

# %%
game_data = pd.read_csv('/datasets/games.csv')
game_data.head(5)
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %%
game_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> После того, как ты рассмотрел данные, стоит составить их краткое описание: указать количество пропусков, аномальные значения типы распределений. Стоит еще выводить статистики с помощью describe() и гистограммы распределений.

# %%
# Приведем названия столбцов к нижнему регистру
game_data.columns = [x.lower() for x in game_data.columns]

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> Правильно привел названия столбцов к нижнему регистру. Это можно было сделать немного иначе: `data.columns = data.columns.str.lower()`

# %%
# Посмотрим общее распределение данных
game_data.hist()
# Out:
# array([[<AxesSubplot:title={'center':'year_of_release'}>,
#         <AxesSubplot:title={'center':'na_sales'}>],
#        [<AxesSubplot:title={'center':'eu_sales'}>,
#         <AxesSubplot:title={'center':'jp_sales'}>],
#        [<AxesSubplot:title={'center':'other_sales'}>,
#         <AxesSubplot:title={'center':'critic_score'}>]], dtype=object)

# %% [markdown]
# Можно заметить, что данные в столбцах (year_of_release,Critic_Score и user_score) распределены нормально

# %% [markdown]
# # 1.2 Обработка пропусков

# %%
game_data.isna().sum()
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating             6766
# dtype: int64

# %% [markdown]
# **Датасет обладает пропусками в следующих столбцах:**
# 1. name
# 2. genre
# 3. year_of_release
# 4. critic_score
# 5. user_score
# 6. rating

# %% [markdown]
# **Оценим количество и характер пропусков в каждом столбце:**

# %%
# Создадим функцию, отражающую процент пропущенных значений в датасете
def print_nan_ratio(column):
    return print('Пропущено {:.1%}'. format(game_data[column].isna().value_counts()[1] / len(game_data), 2) + ' значений')

# %%
print_nan_ratio('year_of_release')
# Out:
# Пропущено 1.6% значений

# %%
# Удалим пропуски
game_data = game_data[~game_data['year_of_release'].isna()]

# %% [markdown]
# Пропуски в данном столбце уместно будет удалить, поскольку потеря в 1,6% данных не приведет к критическим искажениям данных.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Все верно.

# %%
print_nan_ratio('critic_score')
game_data['critic_score'].unique()
# Out:
# Пропущено 51.5% значений
# array([76., nan, 82., 80., 89., 58., 87., 91., 61., 97., 95., 77., 88.,
#        83., 94., 93., 85., 86., 98., 96., 90., 84., 73., 74., 78., 92.,
#        71., 72., 68., 62., 49., 67., 81., 66., 56., 79., 70., 59., 64.,
#        75., 60., 63., 69., 50., 25., 42., 44., 55., 48., 57., 29., 47.,
#        65., 54., 20., 53., 37., 38., 33., 52., 30., 32., 43., 45., 51.,
#        40., 46., 39., 34., 41., 36., 31., 27., 35., 26., 19., 28., 23.,
#        24., 21., 17., 13.])

# %%
print_nan_ratio('user_score')
game_data['user_score'].unique()
# Out:
# Пропущено 40.2% значений
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %%
game_data['user_score'] = game_data['user_score'].replace('tbd', np.NaN)

# %%
print_nan_ratio('rating')
game_data['rating'].unique()
# Out:
# Пропущено 40.6% значений
# array(['E', nan, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %%
# Удалим пропуски в столбце 'name'
game_data = game_data[~game_data['name'].isna()]

# %% [markdown]
# Пропуски в столбце 'name' и 'genre' взаимосвязаны и составляют всего 2 записи. От таких записей тоже следует отказаться

# %% [markdown]
# **Вывод:**
#
# Пропуски в столбцах 'year_of_release', 'name' и 'genre' обработаны путем удаления, поскольку их удельный вес, в первом случае составлял 1,6%, а во втором всего 2 записи.
#
# Пропуски в столбцах 'critic_score', 'user_score' и 'rating' решено не обрабатывать, поскольку удельных вес этих значений составляет: 51.5%, 54.6% и 40.6% соответственно. Логично будет использовать эти данные для анализа продаж по регионам.
#
# Природа наличия пропусков в столбцах 'critic_score', 'user_score' и 'rating' разнообразна.\
#
# **Возможные причины:**
# 1. низкое количество продаж (меньше 0,5 млн копий)
# 2. ранний год выхода игры (до 2000 года)

# %%
game_data[game_data['user_score'].isna()]

# %%
game_data['year_of_release'] = game_data['year_of_release'].astype('int64')
game_data['user_score'] = game_data['user_score'].astype('float64', errors = 'ignore')

# %% [markdown]
# Столбец 'year_of_release' приведен к тпиу int64, поскольку год выпуска не предпологает дробной части\
# Столбец 'user_score' приведен к типу float64, поскольку тип данных object появился из за 'tbd' (to be determinated)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Правильно обработал параметры выше, так держать!

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# Пропуски в признаке рейтинга стоило обработать заглушками. Это позволит в дальнейшем провести более полный и корректный анализ.

# %% [markdown]
# Если честно, то я не совсем понимаю почему мы должны вставлять заглушки, при том что любое вмешательнтство в размере 40 и 50 % от выборки сильно исказит выборку. Однако, вставим значение моды

# %%
#Сохраним моду в переменные и заполним ими пропуски в столбцах
# mode_user_score = game_data['user_score'].mode()[0]
# mode_critic_score = game_data['critic_score'].mode()[0]

# game_data['critic_score'] = game_data['critic_score'].fillna(mode_critic_score)

# game_data['user_score'] = game_data['user_score'].fillna(mode_user_score)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V2<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# Я писал про заглушки в признаке рейтинг ESRB, а не оценок критиков и пользователей, в них как раз нельзя заполнять пропуски. Параметр рейтинга это категориальный признак, заглушкой ты не внесешь искажений, это нужно только для просмотра доли игр без рейтинга.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V3<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Все правильно доработал.

# %% [markdown]
# ## Исследовательский анализ данных

# %%
#Добавим столбец sales_total
game_data['sales_total'] = game_data['eu_sales'] + game_data['eu_sales'] + game_data['jp_sales'] + game_data['other_sales']
game_data
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii             2006        Sports
# 1                  Super Mario Bros.      NES             1985      Platform
# 2                     Mario Kart Wii      Wii             2008        Racing
# 3                  Wii Sports Resort      Wii             2009        Sports
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16711               LMA Manager 2007     X360             2006        Sports
# 16712        Haitaka no Psychedelica      PSV             2016     Adventure
# 16713               Spirits & Spells      GBA             2003      Platform
# 16714            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Суммарные продажи посчитаны верно.

# %% [markdown]
# Посчитаем суммарные продажи во всех регионах за все имеющиеся годы

# %%
games_sales = game_data.pivot_table(index = 'year_of_release', 
                                    values = ['na_sales', 'eu_sales', 'jp_sales', 'other_sales'], 
                                    aggfunc = 'sum')
games_sales.plot(figsize = (14,10))
plt.ylabel('total sales per year')
# Out:
# Text(0, 0.5, 'total sales per year')

# %% [markdown]
# **Вывод:**\
# Среди всех имеющихся рынков (япония, северная америка, европа и иные регионы (детализация не предоставляется)), наиболее высокие показатели продаж имеет регион **"Северная Америка"**. Таким образом американский рынок является **ключевым** с точки зрения прибыли.
#
# На втором месте распологается европейский регион, а 3 место занимает японский рынок.

# %%
games_releases = game_data.pivot_table(index = 'year_of_release', 
                                    values = ['name'], 
                                    aggfunc = 'count').plot(figsize = (10,10))

plt.ylabel('total releases per year')
# Out:
# Text(0, 0.5, 'total releases per year')

# %% [markdown]
# **Вывод**
#
# На данном графике виден отчетливый тренд к увеличению выпуска игр во всех жанрах. Первый скачок произошел в 1995 году, когда корпорация Sony презентовала общественности свою игровую приставку "playstation". После чего принято считать, что игровая индустрия начала свое развитие полноценно.
#
# Наиболее резкий скачок произошел,когда корпроация Sony презентовала "Playstation 2" и окончательно захватила рынок приставок. После чего крупные инвесторы обратили свое внимание на рынок игровой индустрии, что отчетливо видно на графике (период до 2010 года).
#
# Последующий спад выпускаемых релизов обозначен тем, что маленькие студии, боровшиеся за положение в игровой индустрии были поглощены более крупными игроками, такими как Sony, Blizzard, Microsoft, Ubispft, EA и так далее. Подход к созданию игр перешел из экстенсивного к интенсивному (меньшее количество выпускаемых игр, при большей проработанности, размере и рекламных компаниях)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Все так, согласен с тобой.

# %%
#Отберем 10 самых прибыльных платформ и обернем их в список
top_10_platforms = game_data.pivot_table(index = 'platform', 
                      values = 'sales_total', 
                      aggfunc = 'sum').sort_values(by = 'sales_total', ascending = False)[:10].reset_index()
top_10_platforms = top_10_platforms['platform']
top_10_platforms
# Out:
# 0     PS2
# 1     PS3
# 2     Wii
# 3    X360
# 4      DS
# 5      PS
# 6     PS4
# 7      PC
# 8     PSP
# 9     3DS
# Name: platform, dtype: object

# %%
# Отфильтруем значения датаффрейма по 10 самым прибыльным платформам и построим график, отражающий динамику продаж
platform_sales = game_data[(game_data['platform'].isin(top_10_platforms))].pivot_table(index = ['year_of_release'],
                                                                               columns = 'platform',
                                                                               values = 'sales_total', 
                                                                               aggfunc = 'sum')
                           
platform_sales.plot(grid = True, figsize = (14,6))
plt.legend(loc = 'upper right')
plt.title('Динамика объема продаж 10 самых прибыльных платформ', loc = 'center', pad = 10)
plt.xlabel('Год')
plt.ylabel('Объем продаж')
# Out:
# Text(0, 0.5, 'Объем продаж')

# %% [markdown]
# **Вывод:**
#
# На данном графике отражены 10 самых прибыльных платформ, среди которых корпорации Sony принадлежит половина (PS, PS2, PS3, PS4, PSP).
#
# Конкуренцию Sony c их титульной приставкой "PS3" на промежутке 2005 - 2013 составляла Xbox360 от "Microfost", однако так и не смогла подобраться достаточно близко к своему конкуренту.
#
# Третьим игроком на рынке платформ является компания Nintendo (Wii, DS, DS3), упустившая в свое время шанс называться наиболее прибыльной приставкой
#
# Рынок PC (персональные компьютеры) по относительной выручке является самым низкоприбыльным рынком (относительно совокупной прибыли Sony или Nintendo). Это складывается из за политики "эксклюзивных релизов" для конкретной приставки, что заставило потребителей делать выбор в пользу приставки.
#
# Также следует отметить восходщий тренд на покупку старой приставки 3DS от Nintendo, что может говорить о настольгическом тренде по старым играм и приставкам такого типа.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Согласен с твоими выводами, продолжай в том же духе!

# %%
mean_life = platform_sales.pivot_table(index = platform_sales.index, values = platform_sales.columns, aggfunc = 'count').reset_index()
mean_life['mean_life'] = mean_life['3DS'] + mean_life['DS'] + mean_life['PC']+ mean_life['PS']+ mean_life['PS2']+ mean_life['PS3']+ mean_life['PS4']+ mean_life['PSP']+ mean_life['Wii']+ mean_life['X360']

mean_life['const'] = 1
mean_life.groupby(by = 'const')['mean_life'].mean()
# Out:
# const
# 1    4.423077
# Name: mean_life, dtype: float64

# %% [markdown]
# **PS** я знаю, что делать так, как делал это я противозаконно..., но я не придумал более элегантного решения для подсчета
#
# **Среднее** время жизни одной платформы составляет **4,4 года**.

# %% [markdown]
# **Актуальным периодом** назовем период с 2013 по 2016 годы

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Актуальный период подобран абсолютно верно.

# %%
#Отберем 5 самых прибыльных платформ в актуальном периоде и обернем их в список
top_5_platforms_actual = game_data[game_data['year_of_release'] >= 2013].pivot_table(index = 'platform', 
                      values = 'sales_total', 
                      aggfunc = 'sum').sort_values(by = 'sales_total', ascending = False)[:7].reset_index()
top_5_platforms_actual = top_5_platforms_actual['platform']
top_5_platforms_actual
# Out:
# 0     PS4
# 1     PS3
# 2     3DS
# 3    XOne
# 4    X360
# 5    WiiU
# 6      PC
# Name: platform, dtype: object

# %%
# Отфильтруем значения датаффрейма по 5 самым прибыльным платформам в актуальный период 
# и построим график, отражающий динамику продаж
platform_sales_actual = game_data[(game_data['platform'].isin(top_5_platforms_actual) & (game_data['year_of_release'] >= 2013))].pivot_table(index = ['year_of_release'],
                                                                               columns = 'platform',
                                                                               values = 'sales_total', 
                                                                               aggfunc = 'sum')


platform_sales_actual.plot(grid = True, figsize = (14,6))
# plt.set_xticks(2013, 2014, 2015)
plt.legend(loc = 'upper right')
plt.xlim([2013,2016])
plt.title('Динамика объема продаж 5 самых прибыльных платформ в 2013-2016', loc = 'center', pad = 10)
plt.xlabel('Год')
plt.ylabel('Объем продаж')
# Out:
# Text(0, 0.5, 'Объем продаж')

# %%
platform_sales_box = game_data[(game_data['platform'].isin(top_10_platforms))].pivot_table(index = ['name'],
                                                                               columns = 'platform',
                                                                               values = 'sales_total', 
                                                                               aggfunc = 'sum')

# %%
# Построим ящик с "усами" по глобальным продажам в разбивке по платформам
platform_sales_box.boxplot(figsize = (14,9), whiskerprops=dict(color='green'), 
                       capprops=dict(color='green'), 
                       flierprops=dict(marker='o', markersize=5, markeredgecolor='black'), 
                       medianprops=dict(color='black'))
plt.legend(loc = 'upper right')
# plt.set_yscale('log')
plt.title('Ящик с "усами" по 10 самым прибыльным платформам', loc = 'center', pad = 10)
plt.ylim([0, 1])
plt.xlabel('Платформа')
plt.ylabel('Объем продаж')
# Out:
# No handles with labels found to put in legend.
# Text(0, 0.5, 'Объем продаж')

# %% [markdown]
# **КОММЕНТАРИЙ СТУДЕНТА**
# Не знаю способа как построить ящики с усами рядом друг с другом так, чтобы они стояли рядом иначе, по этому сгруппирую данные по наименованию (то есть уровень поднятия будет нулевой и в качестве колонок выставлю платформы, которые соответствуют топ 10 платформам)

# %% [markdown]
# Наибольшая медиана по проданным копиям игр, среди 10 самых прибыльных платформ находится у линейки Sony (PS) и MIcrosoft X360

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# Нужно построить график "ящик с усами" по исходному датафрейму с актуальным периодом. Сейчас ты построил его по сводной таблице, из-за чего на графике отражена не та информация о которой говорится в задании. Когда построишь график, посмотри, чтобы масштаб был нормальным и можно было сравнить статистики разных платформ между собой.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V2<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# Масштаб можно изменить с помощью метода ylim(). Нужно использовать его таким образом, чтобы можно было легко сравнить медианы и квантили продаж разных платформ.
#
# Сам график сейчас ты построил верно, осталось только скорректировать масштаб.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V3<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Замечательно справился с данным пунктом, продолжай в том же духе!

# %% [markdown]
# **Вывод:**
#
# Наибольшую медиану по прибыли показывает приствка PS3, при этом недавно вышедшая приставка PS4 уже почти сравнялась по прибыли с предыдущим поколением PS, что выделяет ее на фоне остальных конкурентов.
#
# Также необходимо отметить прямого конкурента в виде X360, который является единственной альтернативой Sony

# %%
game_data.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8461
# user_score         8981
# rating             6676
# sales_total           0
# dtype: int64

# %%
game_data.corr()
# Out:
#                  year_of_release  na_sales  eu_sales  jp_sales  other_sales  \
# year_of_release         1.000000 -0.092326  0.004045 -0.168477     0.037821
# na_sales               -0.092326  1.000000  0.766546  0.451162     0.638479
# eu_sales                0.004045  0.766546  1.000000  0.435894     0.722679
# jp_sales               -0.168477  0.451162  0.435894  1.000000     0.291562
# other_sales             0.037821  0.638479  0.722679  0.291562     1.000000
# critic_score            0.011411  0.240083  0.221276  0.153474     0.198410
# user_score             -0.267851  0.085549  0.055530  0.126372     0.056935
# sales_total            -0.031205  0.785533  0.973101  0.611670     0.765736
#
#                  critic_score  user_score  sales_total
# year_of_release      0.011411   -0.267851    -0.031205
# na_sales             0.240083    0.085549     0.785533
# eu_sales             0.221276    0.055530     0.973101
# jp_sales             0.153474    0.126372     0.611670
# ...

# %%
# Визуализируем корреляционную матрицу
mask = np.triu(np.ones_like(game_data.corr()))

data_triangle = sns.heatmap(game_data.corr().round(2),
mask=mask,
annot=True,
center = 1,
cmap="flare")

# %% [markdown]
# Визуализируем зависимость продаж от оценок пользователей и оценок притиков

# %%
fig, axs = plt.subplots(1, 2, figsize=(14, 8))

# Строим каждую диаграмму на соответствующей оси 
axs[0].scatter(game_data['critic_score'], game_data['sales_total'])
axs[1].scatter(game_data['user_score'], game_data['sales_total'])

axs[0].set_title('Зависимость оценок критиков от продаж')
axs[1].set_title('Зависимость оценок юзеров от продаж')
axs[0].set_xlabel('Оценки критиков')
axs[1].set_xlabel('Оценки пользователей')
axs[0].set_ylabel('Продажи всего')
axs[1].set_ylabel('Продажи всего')
# Out:
# Text(0, 0.5, 'Продажи всего')

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# Построй диаграммы рассеивания для оценок критков и отдельно для оценок пользователей с помощью метода scatter. Не понимаю почему ты строишь график не по исходному датафрейму, а по сводной таблице уже не первые раз. Если я правильно понял, график ты строишь по датафрейму, в котором находятся значения корреляций.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Правильно сейчас вывел графики, молодец!

# %% [markdown]
# **Вывод:**
#
# Сильной корреляции между продажами и оценками критиков не обнаружено (0,36), при этом наибольшая зависимость (но все равно не существенная) наблюдается на северо-американском рынке (0,41) и в прочих регионах (0,40)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# Тебе нужно рассмотреть сначала одну платформу и выявить какие на ней зависимости от оценок. А затем рассмотреть еще 2-3 топовые платформы.

# %%
fig, axs = plt.subplots(1, 3, figsize=(14, 8))
# Данные для первого графика
x = game_data[game_data['platform'] == 'PS4']['critic_score']
y = game_data[game_data['platform'] == 'PS4']['sales_total']

# Данные для третьего графика
x_1 = game_data[game_data['platform'] == 'XOne']['critic_score']
y_1 = game_data[game_data['platform'] == 'XOne']['sales_total']
# Данные для третьего графика
x_2 = game_data[game_data['platform'] == 'PC']['critic_score']
y_2 = game_data[game_data['platform'] == 'PC']['sales_total']
# Строим каждую диаграмму на соответствующей оси 
axs[0].scatter(x, y)
axs[1].scatter(x_1, y_1)
axs[2].scatter(x_2, y_2)



axs[1].set_title('Зависимость оценок критиков от продажна на топовых платформах')

axs[0].set_xlabel('Оценки критиков PS4')
axs[1].set_xlabel('Оценки критиков XOne')
axs[2].set_xlabel('Оценки критиков PC')
axs[0].set_ylabel('Продажи всего')
axs[1].set_ylabel('Продажи всего')
axs[2].set_ylabel('Продажи всего')
# Out:
# Text(0, 0.5, 'Продажи всего')

# %%
fig, axs = plt.subplots(1, 3, figsize=(14, 8))
# Данные для первого графика
x_3 = game_data[game_data['platform'] == 'PS4']['user_score']
y_3 = game_data[game_data['platform'] == 'PS4']['sales_total']

# Данные для третьего графика
x_4 = game_data[game_data['platform'] == 'XOne']['user_score']
y_4 = game_data[game_data['platform'] == 'XOne']['sales_total']
# Данные для третьего графика
x_5 = game_data[game_data['platform'] == 'PC']['user_score']
y_5 = game_data[game_data['platform'] == 'PC']['sales_total']
# Строим каждую диаграмму на соответствующей оси 
axs[0].scatter(x_3, y_3)
axs[1].scatter(x_4, y_4)
axs[2].scatter(x_5, y_5)



axs[1].set_title('Зависимость оценок пользователей от продажна на топовых платформах')

axs[0].set_xlabel('Оценки критиков PS4')
axs[1].set_xlabel('Оценки критиков XOne')
axs[2].set_xlabel('Оценки критиков PC')
axs[0].set_ylabel('Продажи всего')
axs[1].set_ylabel('Продажи всего')
axs[2].set_ylabel('Продажи всего')
# Out:
# Text(0, 0.5, 'Продажи всего')

# %% [markdown]
# **Вывод**
#
# Оценки критиков и пользователей не оказывают существенного влияния на продажи, что логично поскольку успешность игры зависит от качества самой игры и пиаркомпании вокруг нее

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Абсолютно верно все доработал, так держать!

# %%
game_data['genre'].hist(bins = 12, figsize = (14, 6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Вывод:**
#
# Наибольшее количество игр выпускается в следующих жанрах:
#
# 1. Action
# 2. Sports
# 3. Misc (Miscelaneous)
# 4. Role-playing
# 5. Racing

# %%
#Отберем 10 самых прибыльных платформ и обернем их в список
top_10_genres = game_data.pivot_table(index = 'genre', 
                      values = 'sales_total', 
                      aggfunc = 'sum').sort_values(by = 'sales_total', ascending = False)[:10].reset_index()
top_10_genres = top_10_genres['genre']
top_10_genres
# Out:
# 0          Action
# 1          Sports
# 2    Role-Playing
# 3         Shooter
# 4            Misc
# 5          Racing
# 6        Platform
# 7        Fighting
# 8      Simulation
# 9       Adventure
# Name: genre, dtype: object

# %%
# Отфильтруем значения датаффрейма по 10 самым прибыльным платформам и построим график, отражающий динамику продаж
genre_sales = game_data[(game_data['genre'].isin(top_10_genres) & 
                        (game_data['year_of_release'] >= 2010))].pivot_table(index = ['year_of_release'],
                                                                             columns = 'genre',
                                                                             values = 'sales_total', 
                                                                             aggfunc = 'mean')
                           
genre_sales.plot(grid = True, figsize = (14,6))
plt.legend(loc = 'upper left')
plt.title('Динамика объема средних продаж 10 самых прибыльных жанров', loc = 'center', pad = 10)
plt.xlabel('Год')
plt.ylabel('Общий объем продаж')
# Out:
# Text(0, 0.5, 'Общий объем продаж')

# %% [markdown]
# **в качестве функции аггрегирования теперь стоит средняя**

# %% [markdown]
# **Вывод:** !!новый!!
#
# Среди наиболее прибыльных платформ выделяются наиболее перспективные, с точки зрения динамики, жанра:
# 1. shooter
# 2. platform
# 3. sports
# 4. role-playing

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# В данном случае нужно ориентироваться не только на суммарные продажи, но и на медианные или средние продажи. Суммарные продажи могут некорректно отражать потенциально доходный жанр, так как они завышают ожидаемый от среднестатистической игры доход.
#
# Также нельзя обрезать данные 2016 года, хоть они и не полные, но они отражают самые актуальные тенденции.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Все верно, именно эти жанры наиболее прибыльные на любую среднестатистическую игру.

# %% [markdown]
# **Вывод по разделу 2. Исследовательский анализ данных**
#
# 1. Наиболее прибыльным является рынок северной америки и европейский рынок.
# 2. Динамика выпускаемых игр имела тенденцию к росту вплоть до 2008 года, после чего наблюдается резкий спад, как по количеству выпускаемых проектов, так и по формируемой прибыли (среди причин наиболее вероятна: Глобальный экономический кризис, поглощение большими компаниями небольших студий)
# 3. Среди платформ, нак которых выпускаются игры, наиболее перспективными являются: Playstation от компании Sony (все), приставки Nintendo и традиционный рынок PC
# 4. Средняя продолжительность жизни одной платформы составляет 4 года
# 5. Актуальным периодом будет считаться период с 2013 по 2015 (2016 обладает не полными данными)
# 6. Наибольшая медиана наблюдается у PS3, PS4, X360 и 3DS
# 7. Вопреки ожиданиям, корреляции между мировыми продажами и оценкой критиков не наблюдается. Наибольшая взаимосвязь (при этом все равно низкая) наблюдается у северо-американского региона (0,41) при общей корреляции в 0,36.
# 8. Среди жанров наиболее популярными являются: Action, sports, adventure, misc
# 9. Наиболее перспективные жанры на освнове динамики общей прибыли: action, shooter, role-playing, sports

# %% [markdown]
# ## Портреты пользователей разных регионов

# %%
game_data
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii             2006        Sports
# 1                  Super Mario Bros.      NES             1985      Platform
# 2                     Mario Kart Wii      Wii             2008        Racing
# 3                  Wii Sports Resort      Wii             2009        Sports
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16711               LMA Manager 2007     X360             2006        Sports
# 16712        Haitaka no Psychedelica      PSV             2016     Adventure
# 16713               Spirits & Spells      GBA             2003      Platform
# 16714            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %%
game_data['rating'].unique()
# Out:
# array(['E', nan, 'M', 'T', 'E10+', 'K-A', 'AO', 'EC', 'RP'], dtype=object)

# %%
# очистим данные от пустых значений и будем работать только с полными данными
good_data = game_data

# %%
#Категоризируем данные столбца rating
good_data['rating_new'] = np.select([good_data['rating'] == 'RP',
                                     good_data['rating'].isna(), 
                                     good_data['rating'] == 'EC',
                                     good_data['rating'] == 'K-A',
                                     good_data['rating'] == 'E',
                                     good_data['rating'] == 'E10+',
                                     good_data['rating'] == 'T',
                                     good_data['rating'] == 'M',
                                     good_data['rating'] == 'AO'
                                    ],[0,0,1,2,2,3,4,5,6])
                                   
good_data
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii             2006        Sports
# 1                  Super Mario Bros.      NES             1985      Platform
# 2                     Mario Kart Wii      Wii             2008        Racing
# 3                  Wii Sports Resort      Wii             2009        Sports
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16711               LMA Manager 2007     X360             2006        Sports
# 16712        Haitaka no Psychedelica      PSV             2016     Adventure
# 16713               Spirits & Spells      GBA             2003      Platform
# 16714            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %% [markdown]
# **Пояснение**
#
# Каждому рейтингу присвоено числовое значение от 0 до 6
# рейтинг К-А и Е объеденены в одну группу (2), поскольку являются одинаковыми по слыслу (Kids to Adults и Evereone)
#
# Группы с 1 по 6 отражают возрастные органичения, где 0 - ожидает оценки, 1 - для детей, а 6 - только для взрослых

# %%
# Создадим переменые, хранящие данные по разным регионам 
na_customer = good_data[['year_of_release', 'genre', 'platform','rating_new','na_sales']]
eu_customer = good_data[['year_of_release', 'genre', 'platform','rating_new','eu_sales']]
jp_customer = good_data[['year_of_release', 'genre', 'platform','rating_new','jp_sales']]
other_customer = good_data[['year_of_release', 'genre', 'platform','rating_new','other_sales']]

# %%
# Отберем топ 5 платформ для каждого рынка (на актуальный период)

# NA region
top_5_platforms_na = na_customer[na_customer['year_of_release'] >= 2013].pivot_table(index = 'platform', 
                      values = 'na_sales', 
                      aggfunc = 'sum').sort_values(by = 'na_sales', ascending = False)[:5].reset_index()
top_5_platforms_na = top_5_platforms_na['platform']


# EU region
top_5_platforms_eu = eu_customer[eu_customer['year_of_release'] >= 2013].pivot_table(index = 'platform', 
                      values = 'eu_sales', 
                      aggfunc = 'sum').sort_values(by = 'eu_sales', ascending = False)[:5].reset_index()
top_5_platforms_eu = top_5_platforms_eu['platform']


# JP region
top_5_platforms_jp = jp_customer[jp_customer['year_of_release'] >= 2013].pivot_table(index = 'platform', 
                      values = 'jp_sales', 
                      aggfunc = 'sum').sort_values(by = 'jp_sales', ascending = False)[:5].reset_index()
top_5_platforms_jp = top_5_platforms_jp['platform']


# OTHER region
top_5_platforms_other = other_customer[other_customer['year_of_release'] >= 2013].pivot_table(index = 'platform', 
                      values = 'other_sales', 
                      aggfunc = 'sum').sort_values(by = 'other_sales', ascending = False)[:5].reset_index()
top_5_platforms_other = top_5_platforms_other['platform']

# %%
# Отфильтруем и сгруппируем данные по необходимым регионам

# NORTH AMERICA region
platform_sales_na = na_customer[(na_customer['platform'].isin(top_5_platforms_na) & (na_customer['year_of_release'] >= 2013) & (na_customer['year_of_release'] != 2016))].pivot_table(index = ['platform'],
                                                                               
                                                                               values = 'na_sales', 
                                                                               aggfunc = 'sum').reset_index().sort_values(by = 'na_sales', ascending = False)

# EUROPE region
platform_sales_eu = eu_customer[(eu_customer['platform'].isin(top_5_platforms_eu) & (eu_customer['year_of_release'] >= 2013) & (eu_customer['year_of_release'] != 2016))].pivot_table(index = ['platform'],
                                                                               
                                                                               values = 'eu_sales', 
                                                                               aggfunc = 'sum').reset_index().sort_values(by = 'eu_sales', ascending = False)

# JAPAN region
platform_sales_jp = jp_customer[(jp_customer['platform'].isin(top_5_platforms_jp) & (jp_customer['year_of_release'] >= 2013) & (jp_customer['year_of_release'] != 2016))].pivot_table(index = ['platform'],
                                                                               
                                                                               values = 'jp_sales', 
                                                                               aggfunc = 'sum').reset_index().sort_values(by = 'jp_sales', ascending = False)

# OTHER region
platform_sales_other = other_customer[(other_customer['platform'].isin(top_5_platforms_other) & (other_customer['year_of_release'] >= 2013) & (other_customer['year_of_release'] != 2016))].pivot_table(index = ['platform'],
                                                                               
                                                                               values = 'other_sales', 
                                                                               aggfunc = 'sum').reset_index().sort_values(by = 'other_sales', ascending = False)

# %%
# Создаем фигуру и четыре оси
fig, axs = plt.subplots(1, 4, figsize=(14, 8))

# Строим каждую диаграмму на соответствующей оси
color_rectangle = np.random.rand(7, 3)  
axs[0].barh(platform_sales_na['platform'], platform_sales_na['na_sales'], color = color_rectangle)
axs[1].barh(platform_sales_eu['platform'], platform_sales_eu['eu_sales'], color = color_rectangle)
axs[2].barh(platform_sales_jp['platform'], platform_sales_jp['jp_sales'], color = color_rectangle)
axs[3].barh(platform_sales_other['platform'], platform_sales_other['other_sales'], color = color_rectangle)
axs[0].set_title('Североамериканский регион')
axs[1].set_title('Европейский регион')
axs[2].set_title('Японский регион')
axs[3].set_title('Другие регионы')
# Out:
# Text(0.5, 1.0, 'Другие регионы')

# %% [markdown]
# **Вывод:**
#
# Среди платформ:
#
# **на NA рынке выделяются:**
# 1. X360
# 2. PS4
# 3. XOne
# 4. PS3
# 5. WiiU
#
# **на EU рынке выделяются:**
# 1. PS4
# 2. PS3
# 3. X360
# 4. XOne
# 5. PC
#
# **на JP рынке выделяются:**
# 1. 3DS
# 2. PS3
# 3. WiiU
# 4. PS4
# 5. PSV
#
# **на остальных рынках выделяются:**
# 1. PS4
# 2. PS3
# 3. X360
# 4. XOne
# 5. WiiU
#
# Наиболее похожи европейский рынок и остальные рынки. Больше всего выделяется японский рынок, за счет первенства приставки 3DS

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Все верно рассмотрел, молодец!

# %% [markdown]
# **Теперь жанры**

# %%
na_customer['genre']
# Out:
# 0              Sports
# 1            Platform
# 2              Racing
# 3              Sports
# 4        Role-Playing
#              ...
# 16710          Action
# 16711          Sports
# 16712       Adventure
# 16713        Platform
# 16714      Simulation
# Name: genre, Length: 16444, dtype: object

# %%
# Отберем топ 5 платформ для каждого рынка (на актуальный период)

# NA region
top_5_genres_na = na_customer[na_customer['year_of_release'] >= 2013].pivot_table(index = 'genre', 
                      values = 'na_sales', 
                      aggfunc = 'sum').sort_values(by = 'na_sales', ascending = False)[:5].reset_index()
top_5_genres_na = top_5_genres_na['genre']


# EU region
top_5_genres_eu = eu_customer[eu_customer['year_of_release'] >= 2013].pivot_table(index = 'genre', 
                      values = 'eu_sales', 
                      aggfunc = 'sum').sort_values(by = 'eu_sales', ascending = False)[:5].reset_index()
top_5_genres_eu = top_5_genres_eu['genre']


# JP region
top_5_genres_jp = jp_customer[jp_customer['year_of_release'] >= 2013].pivot_table(index = 'genre', 
                      values = 'jp_sales', 
                      aggfunc = 'sum').sort_values(by = 'jp_sales', ascending = False)[:5].reset_index()
top_5_genres_jp = top_5_genres_jp['genre']


# OTHER region
top_5_genres_other = other_customer[other_customer['year_of_release'] >= 2013].pivot_table(index = 'genre', 
                      values = 'other_sales', 
                      aggfunc = 'sum').sort_values(by = 'other_sales', ascending = False)[:5].reset_index()
top_5_genres_other = top_5_genres_other['genre']

# %%
# Отфильтруем и сгруппируем данные по необходимым регионам

# NORTH AMERICA region
genre_sales_na = na_customer[(na_customer['genre'].isin(top_5_genres_na) & (na_customer['year_of_release'] >= 2013) & (na_customer['year_of_release'] != 2016))].pivot_table(index = ['genre'],
                                                                               
                                                                               values = 'na_sales', 
                                                                               aggfunc = 'sum').reset_index().sort_values(by = 'na_sales', ascending = False)

# EUROPE region
genre_sales_eu = eu_customer[(eu_customer['genre'].isin(top_5_genres_eu) & (eu_customer['year_of_release'] >= 2013) & (eu_customer['year_of_release'] != 2016))].pivot_table(index = ['genre'],
                                                                               
                                                                               values = 'eu_sales', 
                                                                               aggfunc = 'sum').reset_index().sort_values(by = 'eu_sales', ascending = False)

# JAPAN region
genre_sales_jp = jp_customer[(jp_customer['genre'].isin(top_5_genres_jp) & (jp_customer['year_of_release'] >= 2013) & (jp_customer['year_of_release'] != 2016))].pivot_table(index = ['genre'],
                                                                               
                                                                               values = 'jp_sales', 
                                                                               aggfunc = 'sum').reset_index().sort_values(by = 'jp_sales', ascending = False)

# OTHER region
genre_sales_other = other_customer[(other_customer['genre'].isin(top_5_genres_other) & (other_customer['year_of_release'] >= 2013) & (other_customer['year_of_release'] != 2016))].pivot_table(index = ['genre'],
                                                                               
                                                                               values = 'other_sales', 
                                                                               aggfunc = 'sum').reset_index().sort_values(by = 'other_sales', ascending = False)

# %%
# Создаем фигуру и четыре оси
fig, axs = plt.subplots(1, 4, figsize=(14, 8))

# Строим каждую диаграмму на соответствующей оси
color_rectangle = np.random.rand(7, 3)  
axs[0].barh(genre_sales_na['genre'], genre_sales_na['na_sales'], color = color_rectangle)
axs[1].barh(genre_sales_eu['genre'], genre_sales_eu['eu_sales'], color = color_rectangle)
axs[2].barh(genre_sales_jp['genre'], genre_sales_jp['jp_sales'], color = color_rectangle)
axs[3].barh(genre_sales_other['genre'], genre_sales_other['other_sales'], color = color_rectangle)
axs[0].set_title('Североамериканский регион')
axs[1].set_title('Европейский регион')
axs[2].set_title('Японский регион')
axs[3].set_title('Другие регионы')
# Out:
# Text(0.5, 1.0, 'Другие регионы')

# %% [markdown]
# **Вывод:**
#
# Среди платформ:
#
# **на NA рынке выделяются:**
# 1. Action
# 2. Shooter
# 3. Sports
# 4. Role-playing
# 5. Platform
#
# **на EU рынке выделяются:**
# 1. Action
# 2. Shooter
# 3. Sports
# 4. role-playing
# 5. Racing
#
# **на JP рынке выделяются:**
# 1. Action
# 2. role-playing
# 3. Shooter
# 4. Platform
# 5. Misc
#
# **на остальных рынках выделяются:**
# 1. Action
# 2. Shooter
# 3. Sports
# 4. Role-playing
# 5. racing
#
# Наиболее выгодным на всех рынках является жанр Action, жанр Shooter занимает второе место во всех регионах кроме Японии. Остальные места распределены по разному

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> И снова все верно, молодец, что построил графики вместе, чтобы можно было сравнить пользователей между собой.

# %% [markdown]
# **Проверим степень влияния рейтинговых оценок на каждый регион**

# %%
# Оценим отношение проданных копий от от рейтинга ESRB
na_corr = na_customer.pivot_table(index = 'rating_new', 
                           values = 'na_sales',
                           aggfunc = 'sum')


sns.relplot(x=na_corr.index, y='na_sales', data=na_corr, height=4, aspect=1.4)
plt.title('Зависимость проданных копий от от рейтинга ESRB в северо-американском регионе')
plt.ylabel('Количество проданных копий, млн. штук')
plt.xlabel('рейтинг ESRB')
plt.show()

# %%
# Оценим отношение проданных копий от от рейтинга ESRB
eu_corr = eu_customer.pivot_table(index = 'rating_new', 
                           values = 'eu_sales',
                           aggfunc = 'sum')


sns.relplot(x=eu_corr.index, y='eu_sales', data=eu_corr, height=4, aspect=1.4)
plt.title('Зависимость проданных копий от от рейтинга ESRB в европейском регионе')
plt.ylabel('Количество проданных копий, млн. штук')
plt.xlabel('рейтинг ESRB')
plt.show()

# %%
# Оценим отношение проданных копий от от рейтинга ESRB
jp_corr = jp_customer.pivot_table(index = 'rating_new', 
                           values = 'jp_sales',
                           aggfunc = 'sum')


sns.relplot(x=jp_corr.index, y='jp_sales', data=jp_corr, height=4, aspect=1.4)
plt.title('Зависимость проданных копий от от рейтинга ESRB в японском регионе')
plt.ylabel('Количество проданных копий, млн. штук')
plt.xlabel('рейтинг ESRB')
plt.show()

# %%
# Оценим отношение проданных копий от от рейтинга ESRB
other_corr = other_customer.pivot_table(index = 'rating_new', 
                           values = 'other_sales',
                           aggfunc = 'sum')


sns.relplot(x=other_corr.index, y='other_sales', data=other_corr, height=4, aspect=1.4)
plt.title('Зависимость проданных копий от от рейтинга ESRB в остальных регионах')
plt.ylabel('Количество проданных копий, млн. штук')
plt.xlabel('рейтинг ESRB')
plt.show()

# %% [markdown]
# **Вывод:**
#
# 1. Игры ожидающие оценку (группа - 0) следует не учитывать при анализе, тк там содержатся игры совершенно разных возрастных органичений
# 2. Игры для детей возрастом ниже 10 лет (группа - 1) является достаточно нишевой. Потому и количество игр, а соответственно и количество проданных копий находится на невысоком уровне.
# 3. Игры категории "для всех возрастов" (группа - 2) является самой популярной и прибыльной, что логично, поскольку позволяет охватить самый большой возрастной диапазон
# 4. Игры категории "для всех возрастов от 10 лет" (группа - 3) является промежуточной, но при этом игры в данной категории занимают 4 место по проданным копиям
# 5. Игры рейтинга "для подростков" (группа - 4) различаются по регионам, и самым большим показателем обладает японский регион, остальные регионы распределены вокруг схожих значений
# 6. Игры рейтинга "для взрослых старше 17 лет" (группа - 5) имеют раззличные значения в регионах. Самым большим значением выделяется "остальные регионы" и европейский регион
# 7. Игр рейтинга "только для взрослых от 18 лет" (группа - 6) являются шишевыми и аналогично группе 1 не имеют больших показателей по проданным копиям

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# Нужно рассмотреть также игры без рейтинга. Они могут показать особенность какого-нибудь региона.

# %% [markdown]
# **КОММЕНТАРИЙ СТУДЕНТА**
#
# Игры без рейтинга имеют группу (0), то есть ожидающие рейтинга. Если добавить отдельную группу с NaN в анализ, то она покажет наибольший результат, за счет того, что составляет 40% процентов датасета

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V2<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# В этом и суть посмотреть на игры у которых в значении рейтинга стоит NaN. Таким образом ты сможешь увидеть, например, в каком регионе данных рейтинг не пользуется популярностью, а уже затем проверить и обосновать такое поведение.

# %% [markdown]
# **КОММЕНТАРИЙ СТУДЕНТА**
#
# Поправил!

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера V3<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> Стоило описать особенность пользователей из Японии, более 50% игр не имеют рейтинга ESRB, нужно всегда обращать внимание на такие особенности.

# %% [markdown]
# **Вывод:**
#
# 1. Выделены платформы в каждом регионе, выделены наиболее похожие регионы и определены наиболее перспективные площадки в каждом регионе.
# 2. Выделены жанры в каждом регионе, также выделены жанры лидеры по продажам по регионам.
# 3. Визуализирована зависимость проданных копий от возрастного рейтинга игр.

# %% [markdown]
# ## Проверка гипотез

# %%
len(game_data)
# Out:
# 16444

# %%
h_data = game_data[game_data['year_of_release'] >= 2013]
len(h_data)
# Out:
# 2233

# %%
sample_1 = h_data[h_data['platform'] == 'XOne']['user_score']
sample_2 = h_data[h_data['platform'] == 'PC']['user_score']
len(sample_1)
# Out:
# 247

# %%
sample_1.plot(kind='hist', bins=35, alpha=0.6)
sample_2.plot(kind='hist', bins=35, alpha=0.5)
plt.legend(['XOne', 'PC'])
plt.xlabel('Оценка пользователей')
plt.ylabel('Количество оценок')
plt.show()

# %%
sample_action = h_data[h_data['genre'] == 'Action']['user_score']
sample_sports = h_data[h_data['genre'] == 'Sports']['user_score']

# %%
sample_action.plot(kind='hist', bins=35, alpha=0.5)
sample_sports.plot(kind='hist', bins=35, alpha=0.6)
plt.legend(['Action', 'Sports'])
plt.xlabel('Оценка пользователей')
plt.ylabel('Количество оценок')
plt.show()

# %%
from scipy import stats as st

# %% [markdown]
# h0: Средние пользовательские рейтинги платформ Xbox One и PC одинаковые
# h1:
#
# H_0: Средние оценки (user_score) пользователей "XOne" = cредние оценки (user_score) пользователей "PC"`
#
# H_a: Cредние оценки (user_score) пользователей "PC" ≠ cредние оценки (user_score) пользователей "XOne"`
#
# alpha = 0.1

# %%
alpha = 0.01
results = st.ttest_ind(sample_1, sample_2, equal_var = False)

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: nan
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Гипотезу о равенстве средних оценок на платформах XOne и PC не получилось опровергнуть

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# Правильно сформулировал и проверил гипотезы, однако проверять гипотезы нужно на актуальном периоде. Еще раз проверь гипотезы на актуальных данных.

# %% [markdown]
# **КОММЕНТАРИЙ СТУДЕНТА**
# При альфа = 0,01, на актуальном периоде, гипотезу опровергнуть уже не получилось

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Именно так, средние оценки данных платформ примерно равны.

# %% [markdown]
# h0: Средние пользовательские рейтинги платформ Xbox One и PC одинаковые
# h1:
#
# H_0: Средние оценки (user_score) жанра "Action" = cредние оценки (user_score) жанра "Sports"`
#
# H_a: Cредние оценки (user_score) жанра "Action" ≠ cредние оценки (user_score) жанра "Sports"`
#
# alpha = 0.05

# %%
alpha = 0.05
results = st.ttest_ind(sample_action, sample_sports, equal_var = False)

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: nan
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Гипотеза о равенстве средних оценок в жанрах 'Action' и 'Sports' подтверждена

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера V1<a class="tocSkip"></h2>
#
#
# <b>На доработку🤔:</b>
# Ты неправильно проверил гипотезу о неравенстве оценок данных жанров. В качестве нулевой гипотезы ты сформулировал гипотезу о неравенстве средних, а метод ttest_ind проверяет в качестве нулевой гипотезы равенство средних.
#
# Также используй актуальные данные.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V2<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> И снова все верно, молодец!

# %% [markdown]
# **Вывод:**
#
# В качестве проверки гипотез, был использован метод t-тест.
#
# Легитимность использования t-теста обоснована следующими причинами:
#
# 1. Выборочные средние нормально распределены.
# 2. Генеральные совокупности зависят друг от друга.

# %% [markdown]
# ## Вывод:

# %% [markdown]
# Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
# Каждый из пунктов содержит промежуточные выводы
# 1. Данные предобработаны и очищены от пропусков (в там, где это возможно), также для оценок пользователей и критиков поставлены заглушки в виде моды
# 2. Данные проанализированы, визуализированы тренды, выбран актуальный период (2013 - 2016)
# 3. Сформированы портреты пользователей каждого региона
# 4. Проверены гипотезы
#
# **Итоговый вывод:**
#
# **Самые популярные платформы:** Продукты Sony и Nintendo.
#
# **Самые популярные жанры:** экшен, шутер, спорт, ролевые игры и приключения.
#
# **Самая высокая медиана** по количеству проданных копий находится у следующих платформ: PS4/3 XboxOne.
#
# **Корреляция** между оценками критиков и общим количеством проданных копий не была обнаружена.
#
# **Средняя продолжительность жизни платформ** 4,4 года.
#
# **1. Северо-американский регион**
# Является наиболее важным рынком сбыта, в силу наибольшего количества проданных копий в разрезе жанров и платформ.
#
# На этом рынке следует обратить внимание на такие платформы как Xbox One, PS4 и WiiU. Платформу PS3 рассматривать не стоит , поскольку она является устаревшей.
#
# Среди жанров наиболее привлекательными являются: экшн, шутер, спорт, ролевые игры и платформеры
#
#
# **2. Европейский регион**
# Является вторым по важности рынком сбыта, по количеству проданных копий в разрезе жанров и платформ.
#
# На этом рынке следует обратить внимание на такие платформы как PS4, XOne и PC. Платформы PS3 и Xbox360 рассматривать не стоит , поскольку они являются устаревшими.
#
# Среди жанров наиболее привлекательными являются: экшн, шутер, спорт, ролевые игры и гонки
#
#
# **3. Японский регион**
# Является третьим по важности рынком сбыта, по количеству проданных копий в разрезе жанров и платформ.
#
# На этом рынке следует обратить внимание на такие платформы как 3DS, WiiU, PS4, PSV. Платформу PS3 рассматривать не стоит , поскольку она является устаревшей.
#
# Среди жанров наиболее привлекательными являются: экшн, ролевые игры, шутеры, платформеры и смешанные жанры
#
# **P.S.** Следует провести отдельный анализ японского рынка в силу серьезных отличий от остальных регионов.
#
#
# **4. Другие регионы**
# Является 4 по важности рынком сбыта, по количеству проданных копий в разрезе жанров и платформ.
#
# На этом рынке следует обратить внимание на такие платформы как PS4, XOne, WiiU. Платформы PS3 и Xbox360 рассматривать не стоит , поскольку они являются устаревшими.
#
# Среди жанров наиболее привлекательными являются: экшн, шутер, спорт, ролевые игры и гонки
#
#
#
# **Предпочтительные возрастные рейтинги в порядке убывания:** "К-А", "Е", "Е10+", "T", "М"

# %% [markdown]
# **Комментарий студента:** следует подтянуть знания по циклам, поскольку я видел множество возможностей для использования циклов, но не смог придумать как правильно обработать данные с их помощью.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера V1<a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации💡:</b> В итоговом выводе нужно достаточно подробно написать основные пункты выявленных зависимостей. Стоит доработать вывод с учетом моих комментариев по ходу работы. В итоговом выводе также старайся оставлять рекомендации для последующих шагов. Например рекомендации, что можно обработать и проанализировать другие признаки, на что твоим коллегам стоить обратить внимание.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера V3<a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Отличный вывод, все четко, понятно и структурировано. Вывод в полной мере отражает существующие зависимости, и по нему можно принимать дальнейшие решения.
# </div>

# %% [markdown]
# **Большое спасибо за ценные комментарии по работе!!! С каждым последующим кейсов уровень выводов и подхода к обработке данных растет, чему я очень рад!**

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту**
#
# Спасибо за твой проект! Я уверен, что ты приложил все усилия, чтобы сделать этот проект. Это видно по твоей работе, а сформулированные выводы отражают, насколько успешно ты осваиваешь материал.
#
# **Отмечу отдельные положительные моменты проекта🙂**:
#
# * Ты полностью следовал всем этапам выполнения задания и справился почти со всем. Хорошая работа!
# * Отдельно выделю некоторые выводы, которые ты смог сформулировать абсолютно точно!
# * У тебя опрятный и читаемый код. Возможно это звучит банально, однако при работе с чужим кодом это крайне важно)
#
#
# **На что стоит обратить внимание🤓**:
#
# * Важно доработать итоговый вывод.
# * Нужно корректно обработать все признаки.
# * Корректно построй график "ящик с усами".
# * Рассмотри зависимость оценок и продаж для топовых платформ по отдельности.
# * Еще раз проверь гипотезы.
# * Остальные рекомендации ты найдешь в моих комментариях!
#
#
# **Желаю удачи и жду твой проект на повторное ревью!**😉

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **Общий вывод по проекту**
#
# **На что стоит обратить внимание🤓**:
#
# * Важно доработать итоговый вывод.
# * Нужно корректно обработать признак рейтинга ESRB.
# * Скорректируй масштаб графика "ящик с усами".
# * Остальные рекомендации ты найдешь в моих комментариях!
#
#
# **Желаю удачи и жду твой проект на повторное ревью!**😉

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# Ты отлично справился с данной работой! Видно, как ты успешно осваиваешь материал, применяешь полученные знания на практике. Мне было очень приятно проверять твою работу, надеюсь, мои комментарии и советы были для тебя полезными.
#
# **Желаю удачи в последующем обучении и исследованиях!**😉
